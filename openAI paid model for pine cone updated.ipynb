# %%
import openai

# %%
import psycopg2
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
from pinecone.grpc import PineconeGRPC as Pinecone
from sentence_transformers import SentenceTransformer, util
from pinecone import ServerlessSpec
# Database connection details
DATABASE_HOST = "database-test-postgress-instance.cpk2uyae6iza.ap-south-1.rds.amazonaws.com"
DATABASE_USERNAME = "postgres"
DATABASE_PASSWORD = "valign#123"
DATABASE_DB = "zoho_projects_data_v2"
PORT = 5432

# Pinecone details
pinecone_api_key = "pcsk_32zXtP_T9wkSxopwxc5vqKe56jjsi3c2tDysBNighCv4hDx8JtC2MrKduZe1QDKJwf99zX"
index_name = "jagoai"
BATCH_SIZE = 512  # Adjust the batch size to avoid exceeding the size limit

# Function to connect to PostgreSQL database
def connect_to_db():
    try:
        conn = psycopg2.connect(
            dbname=DATABASE_DB,
            user=DATABASE_USERNAME,
            password=DATABASE_PASSWORD,
            host=DATABASE_HOST,
            port=PORT
        )
        return conn
    except psycopg2.Error as e:
        print(f"Error connecting to the database: {e}")
        raise

# Fetch schema with column names and data types, only including string types
def fetch_schema_with_data_types(conn):
    try:
        query = """
         SELECT table_name, column_name, data_type, character_maximum_length
        FROM information_schema.columns
        WHERE table_schema = 'public'
          AND (data_type = 'character varying' OR data_type IN ('text', 'varchar'))
        ORDER BY table_name;
        """
        schema_df = pd.read_sql(query, conn)
        print(schema_df)
        return schema_df
    except Exception as e:
        print(f"Error fetching schema with data types: {e}")
        raise

# Fetch unique values from each column along with table details
def fetch_unique_values(conn, table_name, column_name):
    try:
        query = f"SELECT DISTINCT {column_name} FROM {table_name}"
        df = pd.read_sql(query, conn)
        return df[column_name].dropna().astype(str).tolist()
    except Exception as e:
        print(f"Error fetching unique values for {column_name} in {table_name}: {e}")
        return []

# Fetch all unique values for each column and map them to table details
def fetch_all_unique_values_with_table(conn, schema_df):
    unique_values_dict = {}
    for table_name in schema_df['table_name'].unique():
        unique_values_dict[table_name] = {}
        table_columns = schema_df[schema_df['table_name'] == table_name]
        for column_name in table_columns['column_name']:
            unique_values = fetch_unique_values(conn, table_name, column_name)
            unique_values_dict[table_name][column_name] = unique_values
    return unique_values_dict


# Generate embeddings for each unique value using BERT model
def generate_and_store_embeddings(unique_values_dict):
    openai.api_key='your api key'
    embeddings_dict = {}
    for table_name, columns in unique_values_dict.items():
        embeddings_dict[table_name] = {}
        for column_name, unique_values in columns.items():
            if unique_values:
                unique_values=set(unique_values)
                unique_values=list(unique_values)
                unique_values = [item for item in unique_values if not (isinstance(item, (int, float)) or item is None or item == "")]
                for val in unique_values:
                    print(val)
                    try:
                        #print("unique Values:",unique_values)
                        response = openai.embeddings.create(
                            model="text-embedding-3-large",
                            input=val
                        )
                        embedding = response.data[0].embedding
                        #print("Embeding:",embedding)
                        # Output the embedding
                        embeddings_dict[table_name][column_name] = {
                            "unique_values": val,
                            "embeddings": embedding}
                    except Exception as e:
                        #print("unique_values:",unique_values)
                        print(f"Error generating embeddings for {column_name} in {table_name}: {e}")
                        embeddings_dict[table_name][column_name] = {
                            "unique_values": val,
                            "embeddings": []
                        }
            else:
                print(f"No unique values found for {column_name} in {table_name}. Skipping embeddings.")
    return embeddings_dict

# Initialize Pinecone with Dot Product metric
def initialize_pinecone():
    pc = Pinecone(api_key=pinecone_api_key)
    '''pc.create_index(spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"),
        name=index_name,dimension=768, metric="cosine")'''
    index=pc.Index(index_name)
    return index

# Batch the embeddings for upserts
def batch_embeddings(upsert_data, batch_size):
    for i in range(0, len(upsert_data), batch_size):
        yield upsert_data[i:i + batch_size]

# Upsert embeddings into Pinecone with metadata for each table (namespace)
def upsert_embeddings_into_pinecone(index, embeddings_dict):
    for table_name, columns in embeddings_dict.items():
        print(table_name, columns)
        for column_name, data in columns.items():
            upsert_data = []
            for i, embedding in enumerate(data['embeddings']):
                unique_value = data['unique_values'][i]
                vector_id = f"{table_name}_{column_name}_{i}"
                metadata = {"column_name": column_name, "unique_value": unique_value}

                upsert_data.append({
                    "id": vector_id,
                    "values": embedding,
                    "metadata": metadata
                })

            # Batch the upsert to avoid exceeding size limits
            for batch in batch_embeddings(upsert_data, BATCH_SIZE):
                index.upsert(vectors=batch, namespace=table_name)
                print(f"Upserted batch for {column_name} in {table_name}")

# %%
# Step 1: Connect to the database
conn = connect_to_db()

# Step 2: Fetch the schema with metadata and data types, only for string columns
schema_df = fetch_schema_with_data_types(conn)
print("Schema with string data types fetched successfully.")
# Out:
#                table_name     column_name data_type character_maximum_length
# 0   issues_zoho_projects_     projectname      text                     None
# 1   issues_zoho_projects_   milestonename      text                     None
# 2   issues_zoho_projects_          module      text                     None
# 3   issues_zoho_projects_  classification      text                     None
# 4   issues_zoho_projects_    reproducible      text                     None
# ..                    ...             ...       ...                      ...
# 84   users_zoho_projects_          status      text                     None
# 85   users_zoho_projects_         profile      text                     None
# 86   users_zoho_projects_            role      text                     None
# 87   users_zoho_projects_       useremail      text                     None
# 88   users_zoho_projects_        username      text                     None
#
# [89 rows x 4 columns]
# Schema with string data types fetched successfully.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:45: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   schema_df = pd.read_sql(query, conn)

# %%
# Step 3: Fetch all unique values along with table details
unique_values_dict = fetch_all_unique_values_with_table(conn, schema_df)
print("Unique values for string columns fetched successfully.")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5260\1294891064.py:56: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Error fetching unique values for milestoneurl in milestones_zoho_projects_: Execution failed on sql: SELECT DISTINCT milestoneurl FROM milestones_zoho_projects_
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
# unable to rollback
# Error fetching unique values for milestonename in milestones_zoho_projects_: connection already closed
# Error fetching unique values for delaypercentage in milestones_zoho_projects_: connection already closed
# Error fetching unique values for milestonedelaytime in milestones_zoho_projects_: connection already closed
# Error fetching unique values for flag in milestones_zoho_projects_: connection already closed
# Error fetching unique values for duration in milestones_zoho_projects_: connection already closed
# Error fetching unique values for actualtimetaken in milestones_zoho_projects_: connection already closed
# Error fetching unique values for milestonecompletionmode in milestones_zoho_projects_: connection already closed
# Error fetching unique values for status in milestones_zoho_projects_: connection already closed
# Error fetching unique values for isprivate in project_groups_zoho_projects_: connection already closed
# Error fetching unique values for groupname in project_groups_zoho_projects_: connection already closed
# Error fetching unique values for associatedteams in project_groups_zoho_projects_: connection already closed
# Error fetching unique values for projecturl in projects_zoho_projects_: connection already closed
# Error fetching unique values for healthstatus in projects_zoho_projects_: connection already closed
# Error fetching unique values for timelinestatus in projects_zoho_projects_: connection already closed
# Error fetching unique values for istnm in projects_zoho_projects_: connection already closed
# Error fetching unique values for dealname in projects_zoho_projects_: connection already closed
# Error fetching unique values for planneddurationhours in projects_zoho_projects_: connection already closed
# Error fetching unique values for taskprefix in projects_zoho_projects_: connection already closed
# Error fetching unique values for budgetamount in projects_zoho_projects_: connection already closed
# Error fetching unique values for description in projects_zoho_projects_: connection already closed
# Error fetching unique values for delaydaysasondate in projects_zoho_projects_: connection already closed
# Error fetching unique values for projecteffortsmandays in projects_zoho_projects_: connection already closed
# Error fetching unique values for deliveryteam in projects_zoho_projects_: connection already closed
# Error fetching unique values for status in projects_zoho_projects_: connection already closed
# Error fetching unique values for projectname in projects_zoho_projects_: connection already closed
# Error fetching unique values for budgethours in projects_zoho_projects_: connection already closed
# Error fetching unique values for requiredapps in projects_zoho_projects_: connection already closed
# Error fetching unique values for country in projects_zoho_projects_: connection already closed
# Error fetching unique values for projectendlag in projects_zoho_projects_: connection already closed
# Error fetching unique values for projecttype in projects_zoho_projects_: connection already closed
# Error fetching unique values for key in projects_zoho_projects_: connection already closed
# Error fetching unique values for tagname in tags_zoho_projects_: connection already closed
# Error fetching unique values for tagcolour in tags_zoho_projects_: connection already closed
# Error fetching unique values for currentsprint in tasks_zoho_projects_: connection already closed
# Error fetching unique values for taskname in tasks_zoho_projects_: connection already closed
# Error fetching unique values for description in tasks_zoho_projects_: connection already closed
# Error fetching unique values for priority in tasks_zoho_projects_: connection already closed
# Error fetching unique values for status in tasks_zoho_projects_: connection already closed
# Error fetching unique values for isoverdue in tasks_zoho_projects_: connection already closed
# Error fetching unique values for ownerids in tasks_zoho_projects_: connection already closed
# Error fetching unique values for taskcompletionmode in tasks_zoho_projects_: connection already closed
# Error fetching unique values for claritylevel in tasks_zoho_projects_: connection already closed
# Error fetching unique values for sprint in tasks_zoho_projects_: connection already closed
# Error fetching unique values for billingtype in tasks_zoho_projects_: connection already closed
# Error fetching unique values for productskill in tasks_zoho_projects_: connection already closed
# Error fetching unique values for sprintffsf in tasks_zoho_projects_: connection already closed
# Error fetching unique values for openclosed in tasks_zoho_projects_: connection already closed
# Error fetching unique values for allocatedunallocated in tasks_zoho_projects_: connection already closed
# Error fetching unique values for sprintnew in tasks_zoho_projects_: connection already closed
# Error fetching unique values for qcowner in tasks_zoho_projects_: connection already closed
# Error fetching unique values for tags in tasks_zoho_projects_: connection already closed
# Error fetching unique values for dependencystatus in tasks_zoho_projects_: connection already closed
# Error fetching unique values for taskurl in tasks_zoho_projects_: connection already closed
# Error fetching unique values for associatedproject in teams_zoho_projects_: connection already closed
# Error fetching unique values for teamusers in teams_zoho_projects_: connection already closed
# Error fetching unique values for teamemailalias in teams_zoho_projects_: connection already closed
# Error fetching unique values for description in teams_zoho_projects_: connection already closed
# Error fetching unique values for teamname in teams_zoho_projects_: connection already closed
# Error fetching unique values for name in test: connection already closed
# Error fetching unique values for title in timesheet_zoho_projects_: connection already closed
# Error fetching unique values for approvalstatus in timesheet_zoho_projects_: connection already closed
# Error fetching unique values for istimer in timesheet_zoho_projects_: connection already closed
# Error fetching unique values for type in timesheet_zoho_projects_: connection already closed
# Error fetching unique values for notes in timesheet_zoho_projects_: connection already closed
# Error fetching unique values for status in timesheet_zoho_projects_: connection already closed
# Error fetching unique values for status in users_zoho_projects_: connection already closed
# Error fetching unique values for profile in users_zoho_projects_: connection already closed
# Error fetching unique values for role in users_zoho_projects_: connection already closed
# Error fetching unique values for useremail in users_zoho_projects_: connection already closed
# Error fetching unique values for username in users_zoho_projects_: connection already closed
# Unique values for string columns fetched successfully.

# %%
# Step 5: Generate embeddings for all unique values
embeddings_dict = generate_and_store_embeddings(unique_values_dict)
print("Embeddings for string columns generated successfully.")
# Out:
# Bahwan IT LLC - Zoho one
# A Y & J Solicitors. - Zoho Creator
# Sarthy geotech Zoho Books & Zoho Expense
# Agappe - Zoho CRM Revamp Project
# Ecovinal - Grading Process revaluation CR
# Stanzen Order management
# EMERGING MARKET SOLUTIONS
# Voice Enabled AI Platform - Release 1.0
# Davinci_Zoho Books
# VADM ERP
# Aura_Zoho Books
# RGBSI Zoho Books
# Sona_Zoho CRM_Zoho Books
# IIFL SAMASTA Demand App Implementation CR
# JSW One Platforms - Zoho Creator & Zoho Books | Dedicated Resource
# Cyraacs Zoho People, Zoho Recruit and Zoho Payroll
# Educational Initiatives_CRM CR2022
# Axiobio
# Ecovinal - Zoho Creator - CR
# Amalfiee Ceramics_Zoho Inventory
# Angadi Ventures Pvt. Ltd. Zoho Creator
# VSInterconnect Zoho creator - Inventory and Order Management -Project 1
# Namma Sampradaya_Zoho One
# iDatalytics - Zoho Devt(NMSDC)- Roll Out
# Vestian Global_Zoho Creator
# Moolya_Zoho Books
# IIFl Samasta CPL CR
# Rooman_Zoho Books
# ICAD: Zoho Creator - CR
# Ecovinal - Zoho Creator CR
# Connectivity_Zoho Creator Service Desk
# ROCKSOLID - ZOHO BOOKS - AU
# Ecovinal International Pvt. Ltd.  -  Zoho Creator
# IIFL Samasta Project 4: Zoho CRM
# Educational Initiatives CR - 7
# VSInterconnect Zoho CRM & Zoho Creator
# TMSB Zoho Creator
# 3 .Certification (Revised)
# None
# Manager Dashboard
# QA
# Prequalification
# NEW VA PROJECT TEMPLATE
# Application Submission
# Interview
# Compliance Review
# Desk Audit
# Final Review
# Recertification
# None
# Zoho Technical Blockage
# Commercial
# Functional
# Change Request
# Customer Blockage
# Defect
# Requirement Detailing
# Always
# None
# Sometimes
# Unable
# Not applicable
# External
# Internal
# Open
# Closed
# On Time
# Late
# No
# Yes
# Overdue
# Not Overdue
# Zoho Books
# None
# Milestone One-Advance payment for project initiation
# Milestone Two-Zoho Solution Architect Resource - Zoho Books, ZohoCRM, Zoho Creator & Zoho Analytics
# Portal Website Creation
# Milestone Two-Implementation of Zoho CRM
# Milestone Three- Zoho Books : Financial Accounting Management
# Milestone Two-Zoho CRM, Zoho Analytics & Zoho Creator:1. Requirement discovery2. Development
# Milestone Two- Zoho CRM Implementation
# Milestone Two-Zoho Books:1. Requirement discovery2. Technical Solution documentation & sign-
# Milestone Three-Zoho Recruit – Recruit Management Application1. Requirement discovery2. Techni
# Milestone One-1. Requirement discovery2. Technical Solution documentation & sign-off3. Compl
# Milestone Two-Zoho CRM & Zoho Creator:1.Requirement discovery2. Technical Solution documenta
# No unique values found for issuetype in issues_zoho_projects_. Skipping embeddings.
# 749813000023280810749813000023324389749813000023324393
# 749813000023060812
# 749813000019457089
# 749813000023060812,749813000023231104
# 749813000023386510
# 749813000023193171,749813000023182870
# 749813000022423252749813000021463281749813000023547593
# 749813000023535202
# 749813000019676398
# 749813000022650597
# 749813000023214858
# 749813000021618004
# 749813000019457141
# 749813000023193171
# 749813000008392363749813000023381331749813000023381387749813000023390239
# 749813000021463281749813000023214858
# 749813000023024317,749813000019780222,749813000023060025
# 749813000019676630749813000023324389749813000023324393749813000023024317749813000023029222749813000023201702749813000021438199749813000023390239
# 749813000021451098
# 749813000023324977749813000023361127749813000023390239
# 749813000023309978749813000023060025
# 749813000022953580
# 749813000021463281
# 749813000023324977749813000023060025
# 749813000007582477
# 749813000022584564
# 749813000023303479,749813000023193171,749813000023214874,749813000023221724,749813000023060025
# 749813000023324393
# 749813000023060025,749813000023303479
# 749813000023060025
# 749813000023386510749813000023461683749813000023390239749813000023546163
# 749813000023025422,749813000023029222
# 749813000023024317749813000023029222749813000023126124749813000023390307
# 749813000023324389749813000023324393
# 749813000023024317749813000023324389749813000023324721749813000023029222749813000023060025
# 749813000023324393749813000023060025
# 749813000022650491749813000022650529749813000022650549749813000022650569
# 749813000023460389
# 749813000023324977
# 749813000023060812749813000023324389749813000023324393749813000023231104749813000023221724
# 749813000022865796,749813000023231104,749813000023060812
# 749813000023386510749813000023060025
# 749813000023328001749813000023390307
# 749813000023390307749813000023280810
# 749813000023029222,749813000023085445
# 749813000012850662
# 749813000023024317,749813000023060025
# 749813000018706863749813000023060025
# 749813000023324105749813000023060025
# 749813000023390239
# 749813000023547565
# 749813000023025422,749813000023024317
# 749813000023193171749813000021451098749813000023201702749813000023390239749813000023214858
# 749813000023381331749813000023214858749813000023460389
# 749813000023024317749813000023029222749813000023214874749813000023201702
# 749813000023324721749813000023324389
# 749813000023390307
# 749813000023386510749813000023461683749813000023390239
# 749813000023193171,749813000023231104,749813000023060025
# 749813000023386510749813000023390239
# 749813000023324721
# 749813000023193171749813000023324389749813000023324721
# 749813000023060025,749813000023231104
# 749813000019676630749813000023024317749813000023324389749813000023324393749813000023029222749813000023201702749813000006817003749813000023390239
# 749813000023193171,749813000023324721
# 749813000023060025,749813000023303479,749813000023309544
# 749813000023328001
# 749813000023024317749813000023324389749813000023324721749813000023214858
# 749813000021451098749813000023221724749813000023390239
# 749813000022865796,749813000023231104,749813000023060025,749813000023221724
# 749813000023386510749813000023461683749813000023390239749813000023060025
# 749813000023060025749813000023214858
# 749813000020344315
# 749813000022152239,749813000023060025
# 749813000023024317749813000023324389749813000023324393749813000023029222749813000021438199749813000023201702
# 749813000023193171749813000023324389749813000023324721749813000023390239
# 749813000023381331749813000019457089
# 749813000023060025,749813000023231104,749813000023060812
# 749813000023303479
# 749813000023324105
# 749813000022373929
# 749813000023328001749813000023060025
# 749813000023025422,749813000023024317,749813000023126124
# 749813000023214874749813000023201702749813000023390239
# 749813000018706875
# 749813000023221724
# 749813000023029222749813000023324389749813000023324393749813000023214858749813000023201702
# 749813000023231104
# 749813000023324105749813000023214858
# 749813000023024317749813000023324389749813000023324721749813000023029222749813000023126124749813000023390239
# 749813000023060790
# 749813000023303479,749813000023231104,749813000023221724
# 749813000022152239
# 749813000023221724749813000023024317749813000023324389749813000023324393
# 749813000023029222
# 749813000007480001
# 749813000023024317749813000023324389749813000023324393749813000023029222749813000023201702749813000023390239
# 749813000022865796
# 749813000023386510749813000023460389
# 749813000023193171,749813000021618004
# 749813000023324721749813000023324389749813000023221724749813000023024317
# 749813000023024317
# 749813000023214858,749813000023060025
# No unique values found for associatedteams in issues_zoho_projects_. Skipping embeddings.
# Mail Subject: [## 89086583 ##] RE: SHOWSTOPPER: Integration Issue between CRM and Creator -- ESCALATION
#
# As discussed, When closing a PM, we are  experiencing an issue where the status does not update if it was closed  through other reporting . Do the needful and check. It’s very urgent. PM305490PM197494Ticket : https://desk.zoho.com/agent/valigntechnologies/all/tickets/details/72438000051262025
#
# It's not an issue. it's an CR request.
#
# \
#
# popup UI, affecting back screen save next
#
# Claimed Amount is WrongReference : Jeril CJ Jan 2024
#
# Please refer the below screenshot in Teams Dashbord. Draft Applications should be clickable.
#
# The legend also different in preview aand Apply for cert
#
# Company name - BQR Advertising and Public Relations, Inc.  Duplicating.BQR Advertising and Public Relations, Inc.BQR AdvertisingBQR Advertising
#
# We have wrongly entered the opening balance migration date as 31 March 2021, instead of 31 March 2022.Payment is applied on Opening Balances of contacts, and the system is live from last 6 months, we cannot unmap the transaction against the opening balance.Kindly assist in changing the migration date for the opening balance.Organization ID: 769000373
#
# Edit mode is not working as CS POV
#
# Sort by as a header with (Relevance , Alphabatical Sort , Anuual Revenu(high to Low) , Years in Business (High to Low)) as options.
#
# Customer Record : https://crm.zoho.in/crm/org60003118478/tab/Accounts/84320000002303296
#
# Annual Revenue is not setting up while viewing Saved Search.
#
# The user wants to deduct expense amount spent on respective items mentioned in invoice, and then raise the invoice, Hence the there will be 2 line items:1st line will have positive value2nd line item will have negative valueGST will be applicable to only 1st line itemWe are unable to push negative values to IRP
#
# Ecovinal want the Sales Order validation while Bundling and Bundle of Associated Sales Order validation while Invoicing
#
# Data Added successfully shows in some place but not in otherplace. Make it consistent. Dont show anywhere
#
# After saving the search, Loading Spinner with message as " one moment saving your search" should be displayed and closed automatically in a sec.
#
# Like the below image in books we have a button for "Convert to Invoice" or "Approval" above the PDF view of that report.Like same way we need to do in Zoho creator in that Purchase Order PDF (Page View) Want to show above that they want the Approval option.We need a solution how to archive this
#
# 1) Affidavit Log2) Status Log
#
# Descrion tion field fdor Strtegic Partner Field (need to be larger) -- users data entered was cutoff without any warning  - it should give character count  and limit if necessary. "Extension" field is too wide (should be bearly 6-8 charcter wide, several columns are too wide)
#
# Hi Pranaam,I have been following up with zoho, for the database location change from last week.I don't see any progress, I need your intervention in expediting this.You are looped in the email with subject name  contains "Database Location Change"
#
# Hi Christ,For Client Namma Sampradaya, we are doing the payment integration , they have shared the API Documentation, but I am struck with the errors.And I am having issues in domain verification process.It will be helpful for me , if you can connect today(18-apr-23) in first half
#
# Mail : https://mail.zoho.com/zm/#mail/folder/inbox/p/1705549510584110001Duplicate spare request were generated as there was a delay in success message after adding Spare Request and the user clicks the submit button more than 1 time
#
# Once E-Sign is completed for Cert,Recert and Compliance Review the above screen should be shown
#
# Why semicolon between date and time? should not be
#
# The dropdown value of application is incorrect
#
# By clicking on email log it should open the CRM email directly not the popup
#
# There are chances the same application will get into more than one rule , in that all applicable rules should trigger (App should not be missed from QA)Type of Certification globally should have same value (Lookup)Certification , Recertification, talk to me for remaining.
#
# It should be Days in Stage2) (Act/Pln) should be (Actl/Plnnd)
#
# How to restrict the users from updating specific default fields of Zoho Books. For Example: while creating a invoice the user should be able to change invoice date, terms, tax
#
# Heading name in black bg should be 24px. Questions, subheadings should be 18px, Cancel and Save button, Previous comments and Change log, tables heading name should be 14 px and values should be 12px.​
#
# Davinci is not GST registered, they will raise bills to their vendor where they will pay GST and deduct TDSGST % is not available while creating Bills as they are not GST registered organization
#
# After going to extreme end. No able to move the slider.​
#
# Company name : Cloud 9
#
# Zoho Ticket ID: 4654531I'm facing an Issue in workflow trigger https://books.zoho.in/app/60009086411#/settings/automation/workflows/553403000010367483/editCan you please let us know the exact issue that you are facing? The above workflow does not trigger properly
#
# Hi Zoho Team,We are passing value for quantity & cost price in inventory adjustment via API, but i the cost price are not getting reflected in Zoho Books.Kindly help us on this issue on priorty.4302576
#
# Esign should be available only in preview page not on any other place.
#
# EIN number(enter as per prof view format  - not populating after saving)Phone Num (Entered in diff format, populating in diff format)Certification status (no values are working. not only terminated)​
#
# Yes - comment should be optional, no mandatorySend back to final review should only be a action button not in the formApplication Notes(inside a page should be renamed as Internal Application Notes)
#
# Record : https://crm.zoho.in/crm/org60003118478/tab/Events/84320000872082314When clicking on the Generate Spare Request Blueprint Button the widget's loader is not closing
#
# the sidebar should eb Assessments , button name should be Review Assessments(becuase it is showing both  Desk Audit and InterviewThe Page Title for Ownership Summary Should not be Ownership Summary should be renamed(Discuss with Kris - Supreet)The Question in Final Status of app should be renamed to "Does this company meet the certification qualifications?" Send Update to BE and Raise escalation should only be there in action buttons and not in final status form.In the final Staus of the application No need for Review Assessment button at the top.Move to final Review to rename Ready for Final Review
#
# We are unable to progress on this project as the customer is delaying to share the credentials. We are following up with them from 3 weeks now. Need your support to get credentials and start implementation.
#
# Field : HQQuery Table Link :  https://analytics.zoho.in/workspace/137752000000003001/view/137752000013145002
#
# When I'm adding the Primary Owner for the first time in the system does not populate the fields like:If i do not edit this, I will not be in a position to upload proof of Citizenship and Ethnicity. And the system is not telling me that these field are empty through the error message.
#
# The edit button is not in the correct format. It should look like the edit button in other places of the application. Icon and text of standard font and Blue
#
# Please look at the screenshot, for CS3 QA is shown in the dashboard. It should not be seen.
#
# As discussed Subash Samuthirapandiyan please discuss this with Christ Bellarmine and Selva Bharathi
#
# There should be no bluebar at the top
#
# Please check the attachment for referenceTicket ID 78452394
#
# After Selecting profiles and click pdf and donload no message saying it will be sent via email
#
# When there is no changes made it is showing in the log for documents
#
# Terminated
#
#  Rename the question to Click "Accept" after you have made the requested changes. Comment icon should have round if you have comment in it.
#
# Hi Team,As we are importing the excel file in zoho creator to add the records, like the same way if there is the possible way to import the Text file in zoho creator.Like the below line the data will be there in the Text file "|" this is the separation of the field data in the text file. I have added the text file for your reference PDF.EX : 1|S277|A|STANZEN ENGINEERING PRIVATE LIMITED|1|TKM-PLANT-1|W5|1|11 S277AW5A3519|2021012804|27/01/2021|14:20|28/01/2021|20:55|PW02|14|DY26Z|01|PW02-14|709B-1-WB|28/01/2021|07:25|28/01/2021|20:55|||||||PW02-14||28/01/2021|20:55||||1|53731KK01000|PATCH  FR FENDER APRON  RH|I218|UBDT -   3|100|100|1||3|27/01/2021|14:20|27/01/2021|06:20|27/01/2021|06:20||25/01/2021|06:00|2801|||||||EU4311||164977|Please let us know how to import records using the text file in zoho creator.
#
# In longer term need a new status for document called update requested
#
# Please refer the screenshot below. The Totals should not include Certified, Denied, Terminated or Abondoned Applications.
#
# Dont give edit option for email disable it. If required user will go back to General contact info to edit it.For the eSign The email address on file for the Primary Owner is: [email address]This email will be used to send all documents for electronic signature (eSign) and acknowledgement. Please verify that this is correct for the Primary Owner.If this email is correct, click "Submit" to continue. The Description should be updated for this popup screen.
#
# Discussed during working call
#
# Refer vido recording should be shared by Sunil
#
# The headings like board member etc (in managemet Control , and grid heading )s should be more prominent
#
# Wherever we have more than 6 components in header alignment is disturbed. Correct it n previews as well.
#
# In main page it says Affidavit Log and in popup it says Affidavit logIn Popup L has to be upper case
#
# Kris to provide message
#
#  collapse;width:402pt" width="536" cellspacing="0" cellpadding="0" border="1">Adding   One more Module (Will the contact can be a trust Beneficiary) Sync data from Beneficiary to Contact Having a new section association for Documents UI Update in Tree Structure Creating a Intermediate Preview page for Beneficiaries(No much   Efforts) Recertification Cloning Function Ownership Calculation Logic Including this module in change Log Adding new row  Level Status Updates   and Commenting Additional Error validation messages for trust Ownership Summary Page UI changes (Under Assessment) Etnicity Update option for Trust as well Testing
#
# testing dsdj
#
# this can be a same font size and click Here should be underlined. To View application(instead of form) Click here
#
# All application dropdown should have values like MBE application, MCC Application etc
#
# The stateless form should through alert saying "Have you saved the factors of the current screen" if they say Yes navigatte otherwise stay.
#
# Solution/Change might required.
#
# Agappe made mistake in conveying the issueActual issue is with Area Type where vales (HQ) is missingCaused due to data errorMany data were not availableRelated To : https://projects.zoho.com/portal/valigntechnologies#buginfo/749813000019579031/749813000019919084
#
# Event Link  : https://crm.zoho.in/crm/org60003118478/tab/Events/84320000862923725
#
# 10/23/2024For Recertification - do not require question, "are you previously certified by NMSDC / or Applied"Hiren10/23/2024Operating License Required - is marked as REQUIRED in Application stage but is not marketd required for Recert
#
# all user input  fields in lookup and discovery including keyword search field, should be trimmed before passing to the criteria. Eg: in comp Name if you add comp with 2 to three spaces in front. it is giving 0 result.
#
# No issue since a month
#
# BE POV after update  requested
#
# https://books.zoho.in/app/60009086411#/invoices/553403000014517285
#
# Escalation work Queue Should be clickable for CS4
#
#
#
# Material Deadline" Date Field"Material Required" Text Field"Cover Position" Picklist Field containing 'IFC' or 'OBC'. It can also be filled in free flow text field"Notes" Text FieldEdit The "Amount" Field so that it can contain 'POP' or 'FOC' (part of package or free of charge) this will contain a 0 Value
#
# 1)Application Summary2) Desk Audit3)Assessments4)Internal Application Notes5)Affidavit Log6)Separator Line (---------------------"solid Line")7)FAQs8)Resources
#
# QA Allocation rule  - option for Individual Specific Rules based on their performance , All Manager Role should have access to Rule Configuration
#
# Complaint TAT empty issue : https://projects.zoho.com/portal/valigntechnologies#buginfo/749813000019579031/749813000019919084
#
# They'll create Journal entry for this
#
# Extra White space at right , make notes wider enough to accomodate white space reduce height of notesRemove E.g from this message
#
# 10/23/2024In Profile, logo / viedo etc. was updated  but it missing in their application Hiren10/23/2024Updated logo was uploaded - Please ensure this gets updated in SearchHiren10/23/2024Question: Can we increase video size from 50mb to say 150 mb?
#
# Chat ID: 4804836
#
# Why dev in Coming in prod
#
# 10/23/2024 Optins - defaults were missing (all should be checked and user should be able to uncheck) --  This is conversion issue (unless the user had already Hiren10/23/2024Refernces - E-Mail addresses are required (but in the screen, it is not visible and it is not clear that there is scroll bar)
#
# Follow-up Chat ID: 4710360
#
# Chat ID: #4960115
#
# Status Log , Work Que , Change log , comment Log, Email Log, affidavit Log
#
# Emails are not triggering  for emails address where to address have @agappe.inTested with "vishnu@v-align.in" and "vishnuda373@gmail.com" and for these to address it's working fine
#
# Estimate Template:1. Template background Image should appear only in 1st page2. CGST and SGST should be consolidated and appear in a single column3. Discounted amount be shown
#
# View log does not look like link, it is not following style sheet.
#
# The  quantity slab wise price-list is not reflected when a product is added to cart.I have added a price list which has slabs based on the quantity, this however is not reflected when a product is added to cart. The initial price is still considered as the selling price and not the discounted price
#
# applies to all tables in my work queue and in the desk audit queuesreduce or eliminate scrolling, make labels, clear, correct date/time formats, etc.
#
# Remove "Application wise status"
#
# Ex : https://crm.zoho.in/crm/org60003118478/tab/CustomModule19/84320000795359772
#
# cert status - search not working .Comp Phone Not working(format issues)
#
# question - even in the response should have "S Corp" in paranthesis  Review dropdown values for business structure (Include S-Corp where applicable)
#
# 1. Export UI related issue: On click of Export - > The file type should also have pdf. The Button share via email - pdf is confusing as the file type selected is CSV.2. Share Via Email: The share via email (pdf) should be to Share Via Email which will should give a pop up the enter the recepient email3. Download PDF: On selecting the file type as pdf and click on download, there should be response stating, "We are working on your reqiest. You shall receive an email once the file ready for download"4. If the number of records to download is greater thangreated 200 records, please inser a warning message "Thank you for your request. You shall be allowed to export a max on 200". On click of ok, download the first 250 records.
#
# Make creator form wider for inventory selections.
#
# https://creatorapp.zoho.com/nationalminoritysupplierdeve/environment/development/mbe-and-member-management/#Page:Desk_Audit_3?stage=Management%20Controls&ids=4464717000012164050&IsAudit=&subSection=MCtrl
#
# The heading says Work queue and not my work queue and the font size should be 18 px currently it is 14 px.the table headings should be 16px and the values should be 14px
#
# There should be an option for the staffer to validate  the denial reasons and  factors while doing final review (for denied applications) . The validating authority should have option to edit the factors and reasons.Which Role  will do this validation?(All Escaltion Roles)When it is sent for validation - What should be the application status - Any email notifications? if yes template required. (Same like Escalation Flow)
#
# Distributor Field and Product Fields
#
# 10/23/2024should not be requiring 2024 Revenue -- (we are currently in 2023)Hiren10/23/2024"437,900" should NOT be 2023 number - that should not be the number Hiren10/23/2024Required field for Year should not be allowed to be removed (deleted)​10/23/2024 -Revenue Number - not  allowing prior year to be updated - it says, "You cannot update prior year number" - but letting the users still modify even though the message says otherwise.  There were other inconsistency.This needs to be REVISTED.
#
# Example Record Link : https://crm.zoho.in/crm/org60003118478/tab/CustomModule12/84320000887126404Customer Code : CRM0008315Sales Hierarchy Name : SH-JAN-2024Client's Mail : https://mail.zoho.com/zm/#mail/folder/sent/p/1706803127583110001
#
# When I added a comment against document it should show doc against file name
#
# After a quote comes back Signed Production department members needs to be notified so they can invoice.
#
# Something like this (Talk to Pooja) should be with minimum change
#
# This is to keep you informed , The Aura team is delaying to confirm the  timings for User training session and even after multiple followups the Master data is not been provided for Data Aggregation and Data Migration(Customer master, Vendor master, Item master).We have already dropped them escalating mail twice. Request your support here.
#
# Client reported some fields were empty in Lead ie HQ / Region / ZoneWe fixed it in   : https://projects.zoho.com/portal/valigntechnologies#buginfo/749813000019579031/749813000020051318Need to update the existing Records which were affected
#
# When updating the status of the documents (during desk audit) the page takes about 9 seconds or more to process your update.
#
# https://creatorapp.zoho.com/nationalminoritysupplierdeve/environment/development/mbe-and-member-management/#Page:Final_Review?appId=4464717000013221090
#
# Agappe ( Jiji ) asked to change the functionalityWhen the complaint is of Type "Reagent" then the submit button in the "Spare Request" widget should be disabled
#
# IN Contact Info , subform ,instead of phone Number extension call Phone Ext should be called both primary and alternate number in main form as well preview page as well. Remove extra wisth for all subform fields to avoid scrolling maximum
#
# List View Click to call buttonRename Log Call ButtonEmployee Detail Info HideInclude Group ID for Importion
#
# if tomail and cc mail has same email throw an alert. dont allow
#
# Instead of dots show boxes in that colour (Not filled up)
#
# Through API we are unable to upload the file , even when tried uploading manually we are unable to do it
#
# Places to be address.1. Desk Audit (Move to Assessment)2. Final Review (Move to Final Review, Review Assessment)3. Interview (Review Assessment, Proceed to Interview)4. QA (Move to QA)
#
# Left nav guidlines: LEFT navigation should have 16px font size. 270 width and 45 height and it should have space in between them
#
# Maintain atleast 12px
#
# They'll create Journal entry for this
#
# None
# Show stopper
# Minor
# Critical
# Major
# Blocked
# To be Tested by NMSDC
# To be tested
# In progress
# Reopen
# Open
# Closed
# Need Clarity
# To be Deployed
# Terminated is not giving results in both Discovery and lookup search
# Navigation issue
# For Recert - The Doc Shuld be refered across Applications not only in recent Recert
# pdf Export Issues
# Other reason UI is not proper -
# Name for tabs required for differentiation
# Consistent Field Names
# Duns was shown "Data not provided"
# Spacing issue between document name and the description. little too much space
# Gender and Ethnicity should be enabled for final review and not enable for interview - in assessment screen
# Need an option to go back to contact details from prequal question (For both MCC and MBE)
# Comp Name Happiest Mind - General Bus Info and other section(check), The previous comments were not showing in comment Log
# Not able to add the documents in the Christ individual card
# Draft Applications (CS Dashboard) to be Renamed.
# QA line item is not present in my dashboard
# Crete add facorts hyperlink under every reason wherever factor is applicable / Adjust Add reasons in a way it comes in the same line with reason options.
# Zoho Books: Void Invoice Workflow does not triggering
# Even After entering revenue - Payment is not coming
# Position is fetching Role in all managing Employee - (Have only the Role not position. fetch Role Properly)
# E-Sign confirmation screen
# QA Config - Allocation Percentage - 100 Also should be
# he invoiced Button on the quote must be hidden from everyone except Admins or people from Production and Accounts Departments
# Data present in edit mode but not present in preview
# section wise instructions on color coding not seen
# Slider Issue
# Transfer Order: On Add Row Issue
# BLOCKED: Returned Final Review Application Submission On Success  part
# QA should be present in dashboard only who do the QA
# Minority Investment Fund - Class of shares and changes in investment fund at ownership details
# Why is this UI not as per Earlier in preview page. no segregation bet section names
# Attachment not submitting in CRM from mobile device - Call with Zoho
# None of the Time format should have Seconds in it in the UI
# In Preview Page Onclick Of commen iCon for a sub section - All field level Comments added for that entire section should be visible. Why is it not coming.
# Optimization of Docs Code as per new code in Preview Page
# My work queue issues
# Claim Escalation should be removed and happen on click for the first time
# Home filter is not working for status based filter
# How to get 3 Signature in one purchase order format
# Verify All Document Description does not have typos , punctuation , grammatical errors.
# User Assignment to a Record using multi user lookup
# Other option is not visible for Denial reason
# Rename QA Info to QA Rule
# Workflow not triggering properly for some bills in Books
# Comment log is missing
# What is this "dirty" in change log
# CISCO integration team not available till january-Potential Delay in Go Live
# on Approve , Denial - Preview, not only by email
# When doc status is selected it takes me to top of the screen
# Saved Search - Pagination is not working
# Why edit is coming there - UI Issue(In the Popup)
# Final Review  oR QA transfer Data to MBE search function should be called
# File Preview is not working
# eSign Confirmation Popup
#
# No Respnse from Customer
# UI Issue in PDF
# Downloaded PDF design Issue
# This should be  "Notes" instead of "Add Your Notes"
# Send Update to CS UI to be verified with Hiren
# Add reasons should eb Add/Edit Reasons
# Why do i see null beside save and next button
# Acknowledgement Need for Fiscal Year Issue
# Consumption of Materials Issue
# Buinses Details - allowign edit without clicking Edit
# Column ordered to be corrected and keep it consistent across the application
# [## 83440142 ##] : Auto rejection in Approval Process
# test2
# Saved Search List view (Should be sorted by datetime)
# Field level error message should be different
# UniCommerce API Issue
# Missed Transactions in Stock Inventory Pivot Table
# In popup ownership factor is 1st point but in preview it is showing as 2nd
# QA screen
# Profile Update KT    - Mallesha Selva Christ
# Invoice Creation Restriction
# UI Issue
# CR:Sort Options UI
# Data Added successfully shows in some place but not in otherplace. Make it consistent. Dont show anywhere
# Emails not Triggering : Equipment Purchase Order
# "Individual" - should be "Individuals" (to be consistent) Hiren 10/23/2024 Instructions for Owners screen should have - Individual / Owner (not just Individual) - To be implemented for QA
# Stanzen file parsing
# Vertical Align of columns in Mywork Queue
# Error on Publishing JOPL ERP APP
# Report Regeneration Slowdown Problem
# Filter is not working!!!!
# Spare Request Widget Not Showing Data
# After editing contact info as a CS POV and clicked on save and next instead of business structure it shows data saved successfully
# enable internal comment for documents if you reject the doc
# Applicant company does not have gender and ethnicity box
# Move to QA button is missing
# The order of the section status need to be corrected
# Reordering Left navigation
# There should not seperate accept action required from BE side (This should be automated)
# Change format of timeline. Please display the Pin and Act "Days in Stage" (same info as in Work Queue view) rather than current message format ("1 week since submission")
# Sharing contacts between companies
# Escalation and Level 4 and Above should be seperate role(Roles have to be revisisited)
# Wrong Application Status - Instead of Expired, it should say Denied
# Need to have Recertification "Cheat" sheet
# Re-enter the email in prequal for double check (For both MBE and MCC)
# Escalation resolution to be tracked at section level
# Update Leads Missing Datae
# QA Allocation - Changes
# Report Filter Problem
# During Escalation for escalation owner should the update requested should come only when external comment added
# CRM to Creator Sync Issue
# ownership data duplicating for G2 Esports
# FGNV01 and LDPM004 Issue
# App Status is not changing to final Review in Progress when cliecked from My work Que
# Zoho Finance plus downgrade and upgrade of Zoho Books and Zoho Expense
# Have a clearer test scenarios for the demo tomorrow
# Not able to convert internal to external comment
# Fee has decimals in some places and there is no decimal in other. Please maintain without decimal
# HQ Empty in Complaints TAT
# While I am changing the status to accept this is how it is appearing. Resizing of popup
# Previous button Optimization(Run save only dirty)
# Popup Redirection Problem
# Customer to share the UAT changes
# Comment issue
# Change the button Name to - Save Here not add/edit reasons
# Grading Process Issue
# Item is not visible in regrading
# Budling issue
# After selecting other (with values in the comment box) not displayed here.
# While starting recert i see this page
# Legends has to be corrected
# Need Support on Technical support for Discount feasibility
# Zoho Meetings Activation
# Section level Comment ICon Should also HAs Color Coding according to type of comment
# There should not be popup while you select doc status
# Recert - Field correction
# Bundling problem
# Spare Request Automatically Approved
# Why is the comment  box in different sizes
# Payload size limitation
# On Click of Get New Work (the immediate allocate application should come on top) -- Means it should redirect to the report which is sorted by latest modified data with my work queue
# I have filled reference but it still shows like this in preview page
# After completing answering interview question in ownership details it redirects me to tree structure which it should not
# Required support for Solutioning New CR
# Spelling error - Bradstreet Number
# the first row values should be center aligned
# Selected All resons and submitted (System works wierdly)
# Grading Tracking Account Issue
# Review Assessment Need to be created as a button(redirect to assesment page) , Create Move to Final Review in teh assessment headershould be created in Application Summary Page
# Fields of Recert
# Date is not aligned in affidavit (Signed Document)
# Performance - Page processing time
# Interview status should be printed beside section in Preview Page
# Payment is not Displayed
# Namma Sampradaya Client Database location change
# Once QA is completed as a BE i did not receive an email regarding approval or denial
# Escalation work Queue Should be clickable for CS4
# Reference & Decs formula fields is not working properly
# question - how is S-Corp handled (e.g. how multi corporate - S-Corp would have to be entered)
# UI issue when screen is resized
# Why Totals in dashboard are not clickable
# See alignment
# Colour coding for comments has to be consistent for whole application
# Test
# Documents says missing but not present on screen
# Home Navigation in the Applicant dashboard should redirect MBE Search. Also in   App Dashboard MBE search Should redirect to on top should redirect to dashboard.
# Why is this full caps?
# Delay In Project
# Search Public relations - Duplicate companies
# Bug in DO Goal Commitment
# Issue In Stock Adjustment Solution
# I'm not able to update individual owner status it says all document should have status when i have already marked status for all docs
# Only Manager(With or without escalation role) should have Assign User Option
# Adding Close button at the bottom in Document Scren if freezing is not possible
# Affidavit Log and Email Log should only be for CS not for BE
# While Coming from 4.3 (reference screen is blank , sub section highlight is wrong , tick mark is also coming even there is error)
# QA Allocation Rule
# UI issue (Line not aligned with parent company)
# Comment & Change font size and color across section
# Not as per UI
# Mover up the ownership table higher - (move instrutions lower) in Preview and Submission as well
# After adding all the comments from BE POV for ownership structure I'm still not able to send update
# SP1380 - No Serial Number
# alignment issue here
# Dependent questions are not triggering
# App Summary Should be Highlighted if that section has Comment(Give icon with round at the top)
# PDF Download
# PM Status Is Not Updating
# Grading Tracking A/C Issue
# In Zoho Books, Missing data for Items in both org
# Radio buttons alignment
# Move to Final Review in the assessment Page has rounded corner(Should be corrected). Where as in other place square corner.
# After adding comment why is it redirecting me to main screen Instead of popup
# Grey Out (IFC ) Option
# Move To Final Review Should be there only in Assessment Page and not in Application Summary
# Email Log issue
# Issue in Converting Sale Order to Invoice in Books
# Pagination and Toggle Issue
# Show hide fields issue on Widget
# Facility Information - missing tool tip
# The supporting document text should be 12px
# The Key Employees and Managng employees Column should be same(Same headers like below and above table should be changed)
# Effect to be removed while clicking on this popup
# Comp Reference is empty it should show NA
# Trimming the head and trailing space
# Error message not showing
# Checkbox is displayed while opening popup second Time(while changing factors)
# Multiselect Field Layout Validation.
# Claimed QA is not coming in my work queue
# Grading Duplication Entries
# Ownership percentage is not complete but there is tick mark in the top
# Action UI one below other
# Edit button is different in different places for desk audit.
# ZIP Code validation (Address Validation not only 5 digit)to be added for MBE and MCC prequal
# it should be Add or Edit Reasons and Factors
# IN Recert App (the latest revenue should be blank even if there is a value in original app)
# Adding GST to vendor Bills
# All the fields are filled now it shows error message
# Reset All SHould Optimize
# Case Problem
# Without Submitting Interview Question if next is clicked. We need to through Alert(Solution need to be discussed)
# Complaint- TAT Report > TAT Hours and TAT Days Data not available
# The Font of the entire page and styling (like bold)  has been corrected- should be corrected
# Provide similar spacing as that of section level comment popup
# Drum Consumption
# Issue on Publishing Buyer repayment tagging form in QA
#
# Customer not providing the project closure
# back to Summary Font and styly is not as per UI. Why instead of back to dashboard , back to summary is coming. Thats for recert right?
# Quality Check Issue
# Grading update for Existing Records
# Error is there in side, no error at the top navigation
# esign Affidavit - text changes
# Table layout UI is not complete
# On Send Update to BE
# Update Complaint  with empty HQ
# Review few cosmetic items like the radio button is still not clear
# Customization of Estimates, SO, DC and Invoice template cannot be done as requested by customer
# Profile Update
# The move to interview popup text should be bold.
# The SLA days planned and actual to be split in different columns and very the default sorting on each views
# Recovering Greens Issue
# Terminated Is not working in saved searches
# Transfer Data from Application to Certificates Module.
# "Individual" - should be "Individuals" (to be consistent) Hiren 10/23/2024 Instructions for Owners screen should have - Individual / Owner (not just Individual)
# it alerts to select facor. but while clicking add edit factor the factors are already populating(deve envir)
# Pushing negative values to IRP
# Level 1, 2 and 3 should come in one section ownership summery and managing employess and key employes should come in another section
# Document popup issue
# Option Required for validating the (Denial Reasons)
# On click of cancel of final review popups it redirects me to the previous screen
# correct the subject
# Date and time column is missing in all the log
# section status not wrapping
# hyphen should not be there in recert
# Popups needs to be consistent more polished and looks beutifull
# Restriction of default fields
# Legends are oval in shape. It should be circle
# Commenting should be made mandatory incase of request update from BE
# Save search popup
# Popup resizing while I move to interview
# Left navigation faq has black icon and does not match with the rest of the icons
# it should be Add/Edit Reasons
# Activity Log Submission without Stock Issue
# Having New logic of colour coding for section Level Comment ICon
# During App Submission - onclick of box on ownership Structure(It should directly open Edit screen) for Audit It should be Preview
# Wrong Data in Analytics - CRM > Area Type Master
# Top navigation to be corrected
# Data Prep - Write Scheduler for SLA - Manager Dashboard
# what happedn to top navigation when I am doing desk audit? where is the numbers?
# If NMSDC Certification Yes Only , cert date should be displayed. empty it should not be
# No need for multiple documents for capability statement - should be one doc
# For initial capital contribution add 1 more value make that field as multiselect
#
# Grading Tracking A/C Invoice Issue
# Allignment issue during desk audit!!!!!!
# Geographic market Logic Issue - Catalyst Version
# Actually Role is Sole Proprieter it shows General Partner
# All Emails sent out of the system needs to be logged
# Amalfiee  Delhivery API Issue
# Why is the document section like this?
# The button for move to assessment is missing
# Ownership structure popup should be consistent same like application (bold in application)
# If regional is selected , How come Region can be empty. Is it allowed in app Submission?. Also the other Field should be Region(s) where the region should be captured Regiona
# Search Issue
# The Section Headings of the Form Everywhere should have title case including Preview page
# Go Live Support
# googly eye in assessment form
# 250 maximum record alert is not working on share via email button
# Updating resons and Update (Add , append or remove ) should be implemented properly
# MArk the section level comments in Black
# Auto Logout (Refresh window popup)
# The field is not red
# Alignment Issue header
# Credentials
# BO-HR-Finance Report Issue
# Draft Applications should be clickable
# Discovery Search
# FLSE having Issue with Other Blueprint - Transition : Closed
# Stage is not proper during final Review in dashboard
# This button should appear on the top
# The values are too small in the section level comment box
# Fullfilled By abd DIstributor Loading Issue in Widgets
# Alignment issue. all of them are not aligned properly
# QA witout manager role shoudl eb creaated. QA can be role wihout manager access (no assign User access)
# Search with (Must include capability Statement) - Design Issue
# During Fnal Review in Progress - Ownership Summary is not editable
# Move to QA should come only once the application is claimed and I'm in assesment form just like final review
# on submission redirect back to my work queue
# Tree structure collapsed
# Converted Invoice Not Triggerring
# Ownership - Top Navigation not showing error when there is error in Ind owner.
# PO Number" Field Added to Account Object. This needs to show on the quote if it is filled in.
# Record selection is vanished if header checkbox is clicked from different page
# Overdue values should be in red colour for both the dashboard and my work queue
# Contact Sharing UI
# Batch Tracking Issue
# QA item should not show for USers who do assigned with a role QA
# Do not show Proceed to E-Sign - until READY to be e-Sign
# Header for Interview should look better Alignment
# Colour Coding issue
# Need an option to remove this confirmation whenever a status is selected
# File Tooltip - Update Maximum Filesize and Supported file format
# For Recert / Profile UPdate / Compliance Review(Move To Interview is not next step mandatory0 they can skip and go to final review directly
# BE POV should have message when interview scheduled
# Revenue Error
# Price-list Issue
# Submitted - for E-Sign - it never changed the status to "E-Sign Pending"
# CR Sort Options (Backend)
# Client Not available to start the Project
# The summary has linking structure wrong where as in apply for cert the tree is connected.
# "Individual" - should be "Individuals" (to be consistent)
# Support Need for Payment Integration and Domain Verification
# During Submission of Final Review - Print the preview of the BE email in the same format(rich text) with no editable option.
# "Proceed to E-Sign" -- should be available at the last step (not hjust at top)
# Race / ethnicity should break into next line. give spacing in between
# The Esign Popup message during compliance Review - should be corrected according to MBE perspective
# Change in Opening Balance migration date
# Aligned Council should come after Application Type and move to interview button should be aligned
# Desk Audit Perfomance Issue
# Date of expiry should not be mandatory
# Comment popup UI Checklist
# Section not getting highlighted at top
# There should not be claim button for escalation
# Invoicing Validation in Books
# .00 should not be there on fees
# Even reference is empty while I was during Recert
# Widget Not Loading in IOS Devices
# Management &Control
# After making changes as BE POV I'm not able to send update
# Download affidavit should not appear here and it should come in affidavit log in the left navigation
# No spacing
# Contact Filteration(All individual wners of the company) - for Applicant company Should be done in this place. All Contacts are visible. Auto populate all other fields caaptured in Ind Owners.
# MPC/MCC in lookup screen to be corrected
# BOM UPDATION
# Export UI
# -ve Value for Inventory COA
# if asterisk has empty value field label along with start should be red in add notes field
# Doc Status is not visible if Documents are clicked from Tree box During Final Review
# Loading Icon should be same across the application
# Advance Filter Issues
# Edit Button on Entry of Individual Owner
# Recert instructions coming for new cert application
# Image should not be stretched when previewed
# Also the stage bar in applicant dashboard should not show Interview if interview is skipped
# Side bar navigation - Factors - Should have Stateless forms throwing alert before navigate to Some other facor
# Ownership percentage For Trust and Investment fund
# Grading Process Approval Issue
# Saved Search - Lookup
# Font Issue and font size is not correct
# grammatical Errors - in Accept question
# SLA to be reverified
# Change in Requirement (Kris) -- do not require E-Mail for References during Recertification - only during New Certification it should be required.
# Not for GI Launch - Syncing Proof of expertise across modules
# Books Estimation Template Discount hide and show
# Remove white background from eye and comment
# Ensure all team members receive recertification notices by 9:00 AM EST tomorrow for their respective scenarios.
# Can the field level icons come one below the other like in a straight line?
# This is view mode. Can we remove the box around the value?
# Import data using Text file in zoho creator
# The left navigation is so small and has lot of white space. it is also not consistent with application submission
# Loading Issue in Spare request / Service Request
# Saved searches - Should show only the logged in Company's data
# During Recert why does Business structure says empty
# Final Review Status colour is diff in App Summary and Preview page Header
# Move to assessment Shuld not be there in assesment page itself.
# File Upload Issue
# facors are not clickable not moving any where. How to select ownership, control and procedural factors
# User Not Able to Create Spare Request
# MBE Version 2enable for (RMSDC test logins) toc check data restriction
# Go over Change log and Comment Log for BE POV with Hiren
# Button text should not break
# Transaction failure issue
# If the application is moved to QA CS should not get to know untill and unless it is sent back to final review  by QA
# UI during interview???
# UNSPSC search in Catalyst
# Client refusing to share  MS Azure credentials
# Document action buttons should also be blue (like an action button)
# Update requested email is not triggered
# "Fascility Details" -- shows in Red color (this seems to be the only one in different color)
# Even if there is a issue in the ownership details the top bar is showing tick mark
# Error occurred - while adding notes for the file
# Final Review UI Changes
# test
# When during desk audit for Recert CR i found this issue
# I am not able to filter the application after clicking on values in team dashboard. Check recertification
# Speed Issue - when user clicked on "Submit" - cetification -
# Totals in the team dashboard is wrong
# Revenue on recert
# Remove the border of the Form Container here
# Tank Consumption Not working properly
# Heading not required on this screen
# Should only have option to schedule within 14 days from the day of application moved to virtual interview
# On Click of Preview - from Apply for cert (Dirty Alert should be thrown). Duns Brad street spelling Should be corrected
# Need filters (Like closed application, refer figma) for submitted work queue and draft application
# We need a solution on Custom button in PDF screen
# All application dropdown is exiting the screen
# When the address is out of US State inside US is editable
# #83506395 S2 Score filed not updating in Deals
# Interview scheduled status colour should be grey
# Other should be at last and box should come immediately after other
# Change log issue
# Sales Hierarchy Not Getting Deleted
# When BS is selected as SP and If DBA is given it still shows error icon
# Correction in field
# While update requested after adding all comments under management and control I'm still not able to send update request
# Insitructions for Owners screen should have - Individual / Owner (not just Individual)
# Review few cosmetic items like the radio button is still not clear - App Submission
# Inventory Adjustment Record Deletion Issue
# The progress Bar of dashboard(should have inprog , completed identification ) , certified should be removed
# Comment icon at top should be grey if there are field level comments and comment icon should change if there is section level internal or external comment
# See scroller is there here. Check all side bars and all filter reports from UI
# Make creator form wider for inventory selections.
# Solving Issue for Double render in ruby on rails
# Not able to add Document
# Status not colour coded
# The label and the value should come one below the other just like section 1.1
# Event not Visible in Home Page
# What is this ? Why no data but View option
# Alignment issue in section 2.4
# Auto Select Denial Flow Option while QA Review
# All the navigations should be separated from Action button in Header (Application Summary page- Solution need to be discussed with Hiren
# )
# On the inventory selection creator App the following fields need to be added, and synced down to the Deal and Quote
# Duplicate Spare Request Generated
# When adding ethnicity for company it is redirecting me to my work which should not happen
# I do not even see MIBR in this section!!! why does instruction MIBR data is not completed
# why is there a difference in this popup and comment popup
# Small Changes Raised by Anju
# Close button is missing
# The Work Queue of All CS staffers to be empty.
# Management & Control section is not selected
# Grading Bill-Invoice Confusion
# View in the saved search is not lokk like a clickable one
# Validation And Show hide Issues in Fetch Data Widget
# Recert Validation
# In Ownership section, documents required for if not filled it is not throwing an error
# QA Dashboard Issues
# In Kris Screen - After adding Contact the scroller is not visible(Popup getting cut off)
# [91213091 ] Revaluation issue
# Top header days in stg should be similar to figma
# Upload Document Popup(verify other popups as well)
# tree Structure - Creator Page for unlimited Levels
# No unique values found for milestoneurl in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for milestonename in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for delaypercentage in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for milestonedelaytime in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for flag in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for duration in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for actualtimetaken in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for milestonecompletionmode in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for status in milestones_zoho_projects_. Skipping embeddings.
# No unique values found for isprivate in project_groups_zoho_projects_. Skipping embeddings.
# No unique values found for groupname in project_groups_zoho_projects_. Skipping embeddings.
# No unique values found for associatedteams in project_groups_zoho_projects_. Skipping embeddings.
# No unique values found for projecturl in projects_zoho_projects_. Skipping embeddings.
# No unique values found for healthstatus in projects_zoho_projects_. Skipping embeddings.
# No unique values found for timelinestatus in projects_zoho_projects_. Skipping embeddings.
# No unique values found for istnm in projects_zoho_projects_. Skipping embeddings.
# No unique values found for dealname in projects_zoho_projects_. Skipping embeddings.
# No unique values found for planneddurationhours in projects_zoho_projects_. Skipping embeddings.
# No unique values found for taskprefix in projects_zoho_projects_. Skipping embeddings.
# No unique values found for budgetamount in projects_zoho_projects_. Skipping embeddings.
# No unique values found for description in projects_zoho_projects_. Skipping embeddings.
# No unique values found for delaydaysasondate in projects_zoho_projects_. Skipping embeddings.
# No unique values found for projecteffortsmandays in projects_zoho_projects_. Skipping embeddings.
# No unique values found for deliveryteam in projects_zoho_projects_. Skipping embeddings.
# No unique values found for status in projects_zoho_projects_. Skipping embeddings.
# No unique values found for projectname in projects_zoho_projects_. Skipping embeddings.
# No unique values found for budgethours in projects_zoho_projects_. Skipping embeddings.
# No unique values found for requiredapps in projects_zoho_projects_. Skipping embeddings.
# No unique values found for country in projects_zoho_projects_. Skipping embeddings.
# No unique values found for projectendlag in projects_zoho_projects_. Skipping embeddings.
# No unique values found for projecttype in projects_zoho_projects_. Skipping embeddings.
# No unique values found for key in projects_zoho_projects_. Skipping embeddings.
# No unique values found for tagname in tags_zoho_projects_. Skipping embeddings.
# No unique values found for tagcolour in tags_zoho_projects_. Skipping embeddings.
# No unique values found for currentsprint in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for taskname in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for description in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for priority in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for status in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for isoverdue in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for ownerids in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for taskcompletionmode in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for claritylevel in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for sprint in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for billingtype in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for productskill in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for sprintffsf in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for openclosed in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for allocatedunallocated in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for sprintnew in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for qcowner in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for tags in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for dependencystatus in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for taskurl in tasks_zoho_projects_. Skipping embeddings.
# No unique values found for associatedproject in teams_zoho_projects_. Skipping embeddings.
# No unique values found for teamusers in teams_zoho_projects_. Skipping embeddings.
# No unique values found for teamemailalias in teams_zoho_projects_. Skipping embeddings.
# No unique values found for description in teams_zoho_projects_. Skipping embeddings.
# No unique values found for teamname in teams_zoho_projects_. Skipping embeddings.
# No unique values found for name in test. Skipping embeddings.
# No unique values found for title in timesheet_zoho_projects_. Skipping embeddings.
# No unique values found for approvalstatus in timesheet_zoho_projects_. Skipping embeddings.
# No unique values found for istimer in timesheet_zoho_projects_. Skipping embeddings.
# No unique values found for type in timesheet_zoho_projects_. Skipping embeddings.
# No unique values found for notes in timesheet_zoho_projects_. Skipping embeddings.
# No unique values found for status in timesheet_zoho_projects_. Skipping embeddings.
# No unique values found for status in users_zoho_projects_. Skipping embeddings.
# No unique values found for profile in users_zoho_projects_. Skipping embeddings.
# No unique values found for role in users_zoho_projects_. Skipping embeddings.
# No unique values found for useremail in users_zoho_projects_. Skipping embeddings.
# No unique values found for username in users_zoho_projects_. Skipping embeddings.
# Embeddings for string columns generated successfully.

# %%
import pickle
#save embedings
def save_embeddings_to_pickle(embeddings_dict, file_path):
    try:
        # Save to file
        with open(file_path, "wb") as pickle_file:
            pickle.dump(embeddings_dict, pickle_file)
        print(f"Embeddings successfully saved to {file_path}")
    except Exception as e:
        print(f"Error saving embeddings to Pickle: {e}")

# Example usage
save_embeddings_to_pickle(embeddings_dict, "embeddings_oprnai_emb_large_update_1.pkl")
# Out:
# Embeddings successfully saved to embeddings_oprnai_emb_large_update_1.pkl

# %%
import pickle

def load_embeddings_from_pickle(file_path):
    try:
        with open(file_path, "rb") as pickle_file:
            embeddings_dict = pickle.load(pickle_file)
        print(f"Embeddings successfully loaded from {file_path}")
        return embeddings_dict
    except Exception as e:
        print(f"Error loading embeddings from Pickle: {e}")
        return {}

# %%
embeddings_dict = load_embeddings_from_pickle("embeddings_oprnai_emb_large_update_1.pkl")
# Out:
# Embeddings successfully loaded from embeddings_oprnai_emb_large_update_1.pkl

# %%
def upsert_embeddings_into_pinecone(index, embeddings_dict):
    for table_name, columns in embeddings_dict.items():
        print(f"Processing table: {table_name}")
        for column_name, data in columns.items():
            # Ensure embeddings and unique_values are appropriately structured
            embeddings = data['embeddings']
            if isinstance(data['unique_values'], str):
                # Expand unique_values to match the number of embeddings
                unique_values = [data['unique_values']] * len(embeddings)
            else:
                unique_values = data['unique_values']
            
            # Prepare data for upserting
            upsert_data = []
            for i, embedding in enumerate(embeddings):
                if not isinstance(embedding, list):
                    embedding = [embedding]  # Ensure each embedding is a list

                unique_value = unique_values[i]
                vector_id = f"{table_name}_{column_name}_{i}"
                metadata = {"column_name": column_name, "unique_value": unique_value}

                upsert_data.append({
                    "id": vector_id,
                    "values": embedding,
                    "metadata": metadata
                })

            # Batch the upsert to avoid exceeding size limits
            for batch in batch_embeddings(upsert_data, BATCH_SIZE):
                index.upsert(vectors=batch, namespace=table_name)
                print(f"Upserted batch for column '{column_name}' in table '{table_name}'")

# %%
# Step 6: Initialize Pinecone and upsert embeddings under each table's namespace
pinecone_index = initialize_pinecone()

# %%
upsert_embeddings_into_pinecone(pinecone_index, embeddings_dict)
print("Embeddings upserted into Pinecone successfully.")
# Out:
# Processing table: issues_zoho_projects_
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~\anaconda3\envs\py310\lib\site-packages\pinecone\grpc\base.py:171, in GRPCIndexBase._wrap_grpc_call.<locals>.wrapped()
#     170 try:
# --> 171     return func(
#     172         request,
#     173         timeout=timeout,
#     174         metadata=_metadata,
#     175         credentials=credentials,
#     176         wait_for_ready=wait_for_ready,
#     177         compression=compression,
#     178     )
#     179 except _InactiveRpcError as e:
#
# File ~\anaconda3\envs\py310\lib\site-packages\grpc\_channel.py:1181, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1175 (
#    1176     state,
#    1177     call,
#    1178 ) = self._blocking(
#    1179     request, timeout, metadata, credentials, wait_for_ready, compression
#    1180 )
# -> 1181 return _end_unary_response_blocking(state, call, False, None)
#
# File ~\anaconda3\envs\py310\lib\site-packages\grpc\_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Vector dimension 1 does not match the dimension of the index 3072"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Vector dimension 1 does not match the dimension of the index 3072", grpc_status:3, created_time:"2024-11-28T02:28:30.8003789+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# PineconeException                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 upsert_embeddings_into_pinecone(pinecone_index, embeddings_dict)
#       2 print("Embeddings upserted into Pinecone successfully.")
#
# Cell In[18], line 31, in upsert_embeddings_into_pinecone(index, embeddings_dict)
#      29 # Batch the upsert to avoid exceeding size limits
#      30 for batch in batch_embeddings(upsert_data, BATCH_SIZE):
# ---> 31     index.upsert(vectors=batch, namespace=table_name)
#      32     print(f"Upserted batch for column '{column_name}' in table '{table_name}'")
#
# File ~\anaconda3\envs\py310\lib\site-packages\pinecone\grpc\index_grpc.py:144, in GRPCIndex.upsert(self, vectors, async_req, namespace, batch_size, show_progress, **kwargs)
#     141     return PineconeGrpcFuture(future)
#     143 if batch_size is None:
# --> 144     return self._upsert_batch(vectors, namespace, timeout=timeout, **kwargs)
#     146 if not isinstance(batch_size, int) or batch_size <= 0:
#     147     raise ValueError("batch_size must be a positive integer")
#
# File ~\anaconda3\envs\py310\lib\site-packages\pinecone\grpc\index_grpc.py:177, in GRPCIndex._upsert_batch(self, vectors, namespace, timeout, **kwargs)
#     175 args_dict = self._parse_non_empty_args([("namespace", namespace)])
#     176 request = UpsertRequest(vectors=vectors, **args_dict)
# --> 177 return self._wrap_grpc_call(self.stub.Upsert, request, timeout=timeout, **kwargs)
#
# File ~\anaconda3\envs\py310\lib\site-packages\pinecone\grpc\base.py:182, in GRPCIndexBase._wrap_grpc_call(self, func, request, timeout, metadata, credentials, wait_for_ready, compression)
#     179     except _InactiveRpcError as e:
#     180         raise PineconeException(e._state.debug_error_string) from e
# --> 182 return wrapped()
#
# File ~\anaconda3\envs\py310\lib\site-packages\pinecone\grpc\base.py:180, in GRPCIndexBase._wrap_grpc_call.<locals>.wrapped()
#     171     return func(
#     172         request,
#     173         timeout=timeout,
#    (...)
#     177         compression=compression,
#     178     )
#     179 except _InactiveRpcError as e:
# --> 180     raise PineconeException(e._state.debug_error_string) from e
#
# PineconeException: UNKNOWN:Error received from peer  {grpc_message:"Vector dimension 1 does not match the dimension of the index 3072", grpc_status:3, created_time:"2024-11-28T02:28:30.8003789+00:00"}

# %%
# Assuming `pinecone_index` is your initialized index and `embeddings_dict` contains your data
# `embeddings_dict` is expected to be a dictionary where keys are IDs and values are embeddings

# Displaying the upserted IDs
upserted_ids = list(embeddings_dict.keys())
print("Upserted IDs:", upserted_ids)

# Fetch and display the data for each ID
for id in upserted_ids:
    response = pinecone_index.fetch(ids=[id])
    print(f"Data for ID {id}: {response}")
# Out:
# Upserted IDs: ['issues_zoho_projects_', 'milestones_zoho_projects_', 'project_groups_zoho_projects_', 'projects_zoho_projects_', 'tags_zoho_projects_', 'tasks_zoho_projects_', 'teams_zoho_projects_', 'test', 'timesheet_zoho_projects_', 'users_zoho_projects_']
# Data for ID issues_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID milestones_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID project_groups_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID projects_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID tags_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID tasks_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID teams_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID test: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID timesheet_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}
# Data for ID users_zoho_projects_: {'namespace': '', 'usage': {'read_units': 0}, 'vectors': {}}

# %%
upserted_ids = list(embeddings_dict.keys())

# Fetch all embeddings using their IDs
all_embeddings = {}
for id in upserted_ids:
    response = pinecone_index.fetch(ids=[id])
    all_embeddings[id] = response['vectors'].get(id, {}).get('values', None)

# Display the embeddings
for id, embedding in all_embeddings.items():
    print(f"ID: {id}, Embedding: {embedding}")
# Out:
# ID: issues_zoho_projects_, Embedding: None
# ID: milestones_zoho_projects_, Embedding: None
# ID: project_groups_zoho_projects_, Embedding: None
# ID: projects_zoho_projects_, Embedding: None
# ID: tags_zoho_projects_, Embedding: None
# ID: tasks_zoho_projects_, Embedding: None
# ID: teams_zoho_projects_, Embedding: None
# ID: test, Embedding: None
# ID: timesheet_zoho_projects_, Embedding: None
# ID: users_zoho_projects_, Embedding: None

# %%
upserted_ids = list(embeddings_dict.keys())

# Fetch all embeddings using their IDs and print them
print("All Embedding Values:")
for id in upserted_ids:
    response = pinecone_index.fetch(ids=[id])
    embedding_values = response['vectors'].get(id, {}).get('values', None)
    if embedding_values:
        print(f"ID: {id}, Embedding Values: {embedding_values}")
    else:
        print(f"ID: {id} has no embedding data.")
# Out:
# All Embedding Values:
# ID: issues_zoho_projects_ has no embedding data.
# ID: milestones_zoho_projects_ has no embedding data.
# ID: project_groups_zoho_projects_ has no embedding data.
# ID: projects_zoho_projects_ has no embedding data.
# ID: tags_zoho_projects_ has no embedding data.
# ID: tasks_zoho_projects_ has no embedding data.
# ID: teams_zoho_projects_ has no embedding data.
# ID: test has no embedding data.
# ID: timesheet_zoho_projects_ has no embedding data.
# ID: users_zoho_projects_ has no embedding data.

# %%
#The issue is with single entity should be with single embeding
#Here we are creating single embeding for multiple entities
#Reolve it and unit test in first half(hopefuly the issues should be resolved
